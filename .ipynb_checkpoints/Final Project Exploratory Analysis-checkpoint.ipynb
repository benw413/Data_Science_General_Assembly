# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
at = pd.read_excel('BenHikersInfo.xlsx')

# %%
at.head()
# Out:
#        Finish  AgeYrFin    Race or Heritage StAbbrev Sex Country Hike Type  \
# 0  9 /28/2016      27.0  Caucasian or White       NH   F     USA   Section
# 1  12/31/1936       NaN   Prefer not to say      NaN   M     NaN   Section
# 2  12/31/1939       NaN   Prefer not to say      NaN   M     NaN   Section
# 3  12/31/1939       NaN   Prefer not to say       IL   M     USA   Section
# 4  12/31/1939       NaN   Prefer not to say       IL   F     USA   Section
#
#        Start  Days Elapsed  Yr Comp      ...      SchoolCredit School  \
# 0  3/18/2015         561.0      NaN      ...             False    NaN
# 1        NaN           NaN   1936.0      ...             False    NaN
# 2        NaN           NaN   1939.0      ...             False    NaN
# 3        NaN           NaN   1939.0      ...             False    NaN
# 4        NaN           NaN   1939.0      ...             False    NaN
#
#   Minority MinorityComments  Vegetarian DehydrateOwnFood Giardia   Lyme  \
# 0    False              NaN       False            False   False  False
# 1    False              NaN       False            False   False  False
# 2    False              NaN       False            False   False  False
# 3    False              NaN       False            False   False  False
# 4    False              NaN       False            False   False  False
#
#   Norovirus Disease Other
# 0     False           NaN
# 1     False           NaN
# 2     False           NaN
# 3     False           NaN
# 4     False           NaN
#
# [5 rows x 28 columns]

# %%
at['Hike Type'].value_counts()
# Out:
# NOBO           11138
# Section         3184
# SOBO            1566
# Flip             944
# Alternative      109
# alternative        4
# Alterntive         1
# Yo Yo              1
# Name: Hike Type, dtype: int64

# %%
at['AgeYrFin'].mean()
# Out:
# 36.29236785140702

# %%
at.dropna(subset= ['Hike Type'],inplace = True)

# %%
def clean_8(df):
    to_drop = ['Section','Alternative','Othe','Oher','alternative','Alterntive']
    x = df[df['Hike Type'].isin(to_drop)]
    y = x.index
    df.drop(y,inplace = True)
clean_8(at)

# %%
at['Hike Type'].value_counts()
# Out:
# NOBO     11138
# SOBO      1566
# Flip       944
# Yo Yo        1
# Name: Hike Type, dtype: int64

# %%
at['Sex'].value_counts()
# Out:
# M       10499
# F        3103
# othe        2
# Name: Sex, dtype: int64

# %%
at['Sex'].value_counts()
# Out:
# M       10499
# F        3103
# othe        2
# Name: Sex, dtype: int64

# %%
at.head()
# Out:
#         Finish  AgeYrFin   Race or Heritage StAbbrev Sex Country Hike Type  \
# 8   12/31/1948       NaN  Prefer not to say       PA   M     USA      NOBO
# 9   10/10/1951      28.0  Prefer not to say       CT   M     USA      SOBO
# 10  9 /30/1951       NaN  Prefer not to say       GA   M     USA      NOBO
# 16  9 /25/1955      67.0  Prefer not to say      NaN   F     NaN      NOBO
# 17  9 /15/1957      69.0  Prefer not to say      NaN   F     NaN      NOBO
#
#         Start  Days Elapsed  Yr Comp      ...      SchoolCredit School  \
# 8    1/1/1948         366.0   1948.0      ...             False    NaN
# 9   5/30/1951         134.0   1951.0      ...             False    NaN
# 10  5/31/1951         123.0   1951.0      ...             False    NaN
# 16   5/2/1955         147.0   1955.0      ...             False    NaN
# 17   4/4/1957         165.0   1957.0      ...             False    NaN
#
#    Minority MinorityComments  Vegetarian DehydrateOwnFood Giardia   Lyme  \
# 8     False              NaN       False            False   False  False
# 9     False              NaN       False            False   False  False
# 10    False              NaN       False            False   False  False
# 16    False              NaN       False            False   False  False
# 17    False              NaN       False            False   False  False
#
#    Norovirus Disease Other
# 8      False           NaN
# 9      False           NaN
# 10     False           NaN
# 16     False           NaN
# 17     False           NaN
#
# [5 rows x 28 columns]

# %%
at['Hike Type'].value_counts()
# Out:
# NOBO     11138
# SOBO      1566
# Flip       944
# Yo Yo        1
# Name: Hike Type, dtype: int64

# %%
at.dropna(subset = ['Start'], inplace = True)

# %%
at.head()
# Out:
#         Finish  AgeYrFin   Race or Heritage StAbbrev Sex Country Hike Type  \
# 8   12/31/1948       NaN  Prefer not to say       PA   M     USA      NOBO
# 9   10/10/1951      28.0  Prefer not to say       CT   M     USA      SOBO
# 10  9 /30/1951       NaN  Prefer not to say       GA   M     USA      NOBO
# 16  9 /25/1955      67.0  Prefer not to say      NaN   F     NaN      NOBO
# 17  9 /15/1957      69.0  Prefer not to say      NaN   F     NaN      NOBO
#
#         Start  Days Elapsed  Yr Comp      ...      SchoolCredit School  \
# 8    1/1/1948         366.0   1948.0      ...             False    NaN
# 9   5/30/1951         134.0   1951.0      ...             False    NaN
# 10  5/31/1951         123.0   1951.0      ...             False    NaN
# 16   5/2/1955         147.0   1955.0      ...             False    NaN
# 17   4/4/1957         165.0   1957.0      ...             False    NaN
#
#    Minority MinorityComments  Vegetarian DehydrateOwnFood Giardia   Lyme  \
# 8     False              NaN       False            False   False  False
# 9     False              NaN       False            False   False  False
# 10    False              NaN       False            False   False  False
# 16    False              NaN       False            False   False  False
# 17    False              NaN       False            False   False  False
#
#    Norovirus Disease Other
# 8      False           NaN
# 9      False           NaN
# 10     False           NaN
# 16     False           NaN
# 17     False           NaN
#
# [5 rows x 28 columns]

# %%
at['Start_Date'] = pd.to_datetime(at['Start'])

# %%
x = at['Start_Date'].dt.year

# %%
x.nsmallest
# Out:
# <bound method Series.nsmallest of 8        1948
# 9        1951
# 10       1951
# 16       1955
# 17       1957
# 20       1959
# 36       1965
# 38       1965
# 43       1967
# 48       1968
# 50       1969
# 57       1969
# 70       1970
# 89       1971
# 94       1971
# 102      1972
# 115      1972
# 130      1972
# 131      1972
# 132      1973
# 133      1973
# 149      1973
# 156      1973
# 169      1973
# 173      1973
# 174      1973
# 192      1973
# 193      1973
# 194      1973
# 203      1973
#          ...
# 17800    2016
# 17801    2016
# 17802    2016
# 17803    2016
# 17804    2016
# 17806    2016
# 17807    2016
# 17808    2016
# 17809    2016
# 17810    2016
# 17813    2016
# 17814    2016
# 17815    2016
# 17816    2016
# 17817    2016
# 17819    2016
# 17820    2016
# 17822    2016
# 17823    2016
# 17824    2016
# 17825    2016
# 17826    2016
# 17827    2016
# 17828    2016
# 17829    2016
# 17830    2016
# 17831    2016
# 17832    2016
# 17833    2016
# 17834    2016
# Name: Start_Date, dtype: int64>

# %%
plt.figure(figsize = (10,10))
sns.heatmap(at.corr(),annot = True)

# %%
z = at.isnull().sum()
z.plot(kind = 'bar')

# %%
at['AgeYrFin'].mean()
# Out:
# 32.75476394849785

# %%
at['AgeYrFin'].min()
# Out:
# -30.0

# %%
at['AgeYrFin'].max()
# Out:
# 81.0

# %%
at['Sex'].value_counts()
# Out:
# M       10329
# F        3057
# othe        2
# Name: Sex, dtype: int64

# %%
at.head()
# Out:
#         Finish  AgeYrFin   Race or Heritage StAbbrev Sex Country Hike Type  \
# 8   12/31/1948       NaN  Prefer not to say       PA   M     USA      NOBO
# 9   10/10/1951      28.0  Prefer not to say       CT   M     USA      SOBO
# 10  9 /30/1951       NaN  Prefer not to say       GA   M     USA      NOBO
# 16  9 /25/1955      67.0  Prefer not to say      NaN   F     NaN      NOBO
# 17  9 /15/1957      69.0  Prefer not to say      NaN   F     NaN      NOBO
#
#         Start  Days Elapsed  Yr Comp    ...     School Minority  \
# 8    1/1/1948         366.0   1948.0    ...        NaN    False
# 9   5/30/1951         134.0   1951.0    ...        NaN    False
# 10  5/31/1951         123.0   1951.0    ...        NaN    False
# 16   5/2/1955         147.0   1955.0    ...        NaN    False
# 17   4/4/1957         165.0   1957.0    ...        NaN    False
#
#    MinorityComments Vegetarian  DehydrateOwnFood Giardia   Lyme  Norovirus  \
# 8               NaN      False             False   False  False      False
# 9               NaN      False             False   False  False      False
# 10              NaN      False             False   False  False      False
# 16              NaN      False             False   False  False      False
# 17              NaN      False             False   False  False      False
#
#    Disease Other Start_Date
# 8            NaN 1948-01-01
# 9            NaN 1951-05-30
# 10           NaN 1951-05-31
# 16           NaN 1955-05-02
# 17           NaN 1957-04-04
#
# [5 rows x 29 columns]

# %%
at.index
# Out:
# Int64Index([    8,     9,    10,    16,    17,    20,    36,    38,    43,
#                48,
#             ...
#             17825, 17826, 17827, 17828, 17829, 17830, 17831, 17832, 17833,
#             17834],
#            dtype='int64', length=13433)

# %%
at['Country'].value_counts()
# Out:
# USA                        12775
# Canada                       133
# GERMANY                       79
# England                       64
# CANADA                        48
# Germany                       41
# Australia                     38
# UK                            38
# New Zealand                   19
# THE NETHERLANDS               18
# SWITZERLAND                   17
# ENGLAND                       13
# Israel                        12
# AUSTRALIA                     11
# UNITED KINGDOM                 9
# Switzerland                    9
# Ireland                        6
# JAPAN                          5
# France                         5
# Great Britain                  5
# Japan                          5
# Norway                         4
# NEW ZEALAND                    4
# Belgium                        4
# AUSTRIA                        4
# South Africa                   3
# IRELAND                        3
# Czech Republic                 3
# ITALY                          3
# Singapore                      2
#                            ...
# Denmark                        2
# GREAT BRITAIN                  1
# Morocco (North Africa)         1
# Austria                        1
# Romania                        1
# Finland                        1
# Spain                          1
# DENMARK                        1
# Bahamas                        1
# SWEDEN                         1
# GUAM                           1
# India                          1
# Wales                          1
# South Korea                    1
# FINLAND                        1
# VENEZUELA                      1
# BELGIUM                        1
# Barbados                       1
# UNITED KINGDOMUK               1
# Scotland                       1
# Mexico                         1
# SPAIN                          1
# Philippines                    1
# ENGLAND, UNITED KINGDOM        1
# PORTUGAL                       1
# Taiwan                         1
# Italy                          1
# EGYPT                          1
# CHINA                          1
# NORWAY                         1
# Name: Country, dtype: int64
